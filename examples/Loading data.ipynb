# %%
from saliency import SaliencyClient
from matplotlib.pyplot import imshow
# %matplotlib inline

sapi = SaliencyClient("test0824", "Qwer!234")

# %%
sapi.add_study("test.csv","oai")
# Out:
# Study has been created
# {'id': 47,
#  'name': 'oai',
#  'file': 'https://storage.googleapis.com/saliency-storage/files/studies/5/oai/test.csv',
#  'created_at': '2019-09-07T05:32:52.459977Z',
#  'updated_at': '2019-09-07T05:32:52.460025Z'}

# %%
sapi.add_annotation_scheme("Knee structures", "segmentation", [
    "Femoral Cartilage",
	"Lateral Meniscus",
	"Lateral Tibial Cartilage",
	"Medial Meniscus",
	"Medial Tibial Cartilage",
	"Patellar Cartilage"
])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-00587c812eb3> in <module>
# ----> 1 sapi.add_annotation_scheme("Knee structures", "segmentation", [
#       2     "Femoral Cartilage",
#       3         "Lateral Meniscus",
#       4         "Lateral Tibial Cartilage",
#       5         "Medial Meniscus",
#
# AttributeError: 'SaliencyClient' object has no attribute 'add_annotation_scheme'

# %%
sapi.add_task("Knee structures", ["oai", "nhs"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-0ccb78f63e49> in <module>
# ----> 1 sapi.add_task("Knee structures", ["oai", "nhs"])
#
# AttributeError: 'SaliencyClient' object has no attribute 'add_task'

# %%
datapoints = sapi.download_datapoints()
X,Y = sapi.create_arrays(datapoints,1024,1024)

# %%
imshow(X[0,:,:])

# %%
imshow(Y[0])
